# %%
from __future__ import annotations

import operator, os
from pathlib import Path
from typing import TypedDict, List, Optional, Annotated, NotRequired, Literal

from pydantic import BaseModel, Field
from langgraph.graph import StateGraph, START, END
from langgraph.types import Send

from langchain_openai import ChatOpenAI
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_groq import ChatGroq
from langchain_core.messages import SystemMessage, HumanMessage
from langchain_community.tools.tavily_search import TavilySearchResults
from dotenv import load_dotenv

# %%
class Task(BaseModel):
    id: int
    title: str

    goal: str = Field(
        ...,
        description="One sentence describing what the reader should be able to do/understand after this section.",
    )
    bullets: List[str] = Field(
        ...,
        min_length=3,
        max_length=6,
        description="3–6 concrete, non-overlapping subpoints to cover in this section.",
    )
    target_words: int = Field(..., description="Target word count for this section (120–550).")

    tags: List[str] = Field(default_factory=list)
    requires_research: bool = False
    requires_citations: bool = False
    requires_code: bool = False

# %%
class Plan(BaseModel):
    blog_title: str
    audience: str
    tone: str
    blog_kind: Literal["explainer", "tutorial", "news_roundup", "comparison", "system_design"] = "explainer"
    constraints: List[str] = Field(default_factory=list)
    tasks: List[Task]

# %%
class EvidenceItem(BaseModel):
    title: str
    url: str
    published_at: Optional[str] = None
    snippet: Optional[str] = None
    source: Optional[str] = None


class RouterDecision(BaseModel):
    needs_research: bool
    mode: Literal["closed_book", "hybrid", "open_book"]
    queries: List[str] = Field(default_factory=list)


class EvidencePack(BaseModel):
    evidence: List[EvidenceItem] = Field(default_factory=list)

# %%
class State(TypedDict):
    topic: str

    # routing / research
    mode: NotRequired[str]
    needs_research: NotRequired[bool]
    queries: NotRequired[List[str]]
    evidence: NotRequired[List[EvidenceItem]]

    plan: NotRequired[Plan]

    # workers
    sections: Annotated[List[tuple[int, str]], operator.add]
    final: NotRequired[str]

# %%
load_dotenv(Path(".env"), override=True)
llm = ChatGoogleGenerativeAI(
    model="gemma-4-31b-it",
    google_api_key=os.getenv("GOOGLE_API_KEY"),
)

# %%
ORCH_SYSTEM = """You are a senior technical writer and developer advocate.
Your job is to produce a highly actionable outline for a technical blog post.

Hard requirements:
- Create 5–9 sections (tasks) suitable for the topic and audience.
- Each task must include:
  1) goal (1 sentence)
  2) 3–6 bullets that are concrete, specific, and non-overlapping
  3) target word count (120–550)

Quality bar:
- Assume the reader is a developer; use correct terminology.
- Bullets must be actionable: build/compare/measure/verify/debug.
- Ensure the overall plan includes at least 2 of these somewhere:
  * minimal code sketch / MWE (set requires_code=True for that section)
  * edge cases / failure modes
  * performance/cost considerations
  * security/privacy considerations (if relevant)
  * debugging/observability tips

Grounding rules:
- Mode closed_book: keep it evergreen; do not depend on evidence.
- Mode hybrid:
  - Use evidence for up-to-date examples (models/tools/releases) in bullets.
  - Mark sections using fresh info as requires_research=True and requires_citations=True.
- Mode open_book:
  - Set blog_kind = "news_roundup".
  - Every section is about summarizing events + implications.
  - DO NOT include tutorial/how-to sections unless user explicitly asked for that.
  - If evidence is empty or insufficient, create a plan that transparently says "insufficient sources"
    and includes only what can be supported.

Output must strictly match the Plan schema.
"""

def orchestrator_node(state: State) -> dict:
    planner = llm.with_structured_output(Plan)

    evidence = state.get("evidence", [])
    mode = state.get("mode", "closed_book")

    plan = planner.invoke(
        [
            SystemMessage(content=ORCH_SYSTEM),
            HumanMessage(
                content=(
                    f"Topic: {state['topic']}\n"
                    f"Mode: {mode}\n\n"
                    f"Evidence (ONLY use for fresh claims; may be empty):\n"
                    f"{[e.model_dump() for e in evidence][:16]}"
                )
            ),
        ]
    )

    return {"plan": plan}

# %%
def fanout(state: State):
    return [
        Send(
            "worker",
            {
                "task": task.model_dump(),
                "topic": state["topic"],
                "mode": state.get("mode", ""),
                "plan": state["plan"].model_dump(),
                "evidence": [e.model_dump() for e in state.get("evidence", [])],
            },
        )
        for task in state["plan"].tasks
    ]

# %%
WORKER_SYSTEM = """You are a senior technical writer and developer advocate.
Write ONE section of a technical blog post in Markdown.

Hard constraints:
- Follow the provided Goal and cover ALL Bullets in order (do not skip or merge bullets).
- Stay close to Target words (\u00b115%).
- Output ONLY the section content in Markdown (no blog title H1, no extra commentary).
- Start with a '## <Section Title>' heading.

Scope guard:
- If blog_kind == "news_roundup": do NOT turn this into a tutorial/how-to guide.
  Do NOT teach web scraping, RSS, automation, or "how to fetch news" unless bullets explicitly ask for it.
  Focus on summarizing events and implications.

Grounding policy:
- If mode == open_book:
  - Do NOT introduce any specific event/company/model/funding/policy claim unless it is supported by provided Evidence URLs.
  - For each event claim, attach a source as a Markdown link: ([Source](URL)).
  - Only use URLs provided in Evidence. If not supported, write: "Not found in provided sources."
- If requires_citations == true:
  - For outside-world claims, cite Evidence URLs the same way.
- Evergreen reasoning is OK without citations unless requires_citations is true.

Code:
- If requires_code == true, include at least one minimal, correct code snippet relevant to the bullets.

Style:
- Short paragraphs, bullets where helpful, code fences for code.
- Avoid fluff/marketing. Be precise and implementation-oriented.
"""

def worker_node(payload: dict) -> dict:

    task = Task(**payload["task"])
    plan = Plan(**payload["plan"])
    evidence = [EvidenceItem(**e) for e in payload.get("evidence", [])]
    topic = payload["topic"]
    mode = payload.get("mode", "closed_book")

    bullets_text = "\n- " + "\n- ".join(task.bullets)

    evidence_text = ""
    if evidence:
        evidence_text = "\n".join(
            f"- {e.title} | {e.url} | {e.published_at or 'date:unknown'}".strip()
            for e in evidence[:20]
        )

    response = llm.invoke(
        [
            SystemMessage(content=WORKER_SYSTEM),
            HumanMessage(
                content=(
                    f"Blog title: {plan.blog_title}\n"
                    f"Audience: {plan.audience}\n"
                    f"Tone: {plan.tone}\n"
                    f"Blog kind: {plan.blog_kind}\n"
                    f"Constraints: {plan.constraints}\n"
                    f"Topic: {topic}\n"
                    f"Mode: {mode}\n\n"
                    f"Section title: {task.title}\n"
                    f"Goal: {task.goal}\n"
                    f"Target words: {task.target_words}\n"
                    f"Tags: {task.tags}\n"
                    f"requires_research: {task.requires_research}\n"
                    f"requires_citations: {task.requires_citations}\n"
                    f"requires_code: {task.requires_code}\n"
                    f"Bullets:{bullets_text}\n\n"
                    f"Evidence (ONLY use these URLs when citing):\n{evidence_text}\n"
                )
            ),
        ]
    )
    content = response.content
    if isinstance(content, list):
        content = "\n".join(
            part.get("text", "")
            for part in content
            if isinstance(part, dict) and part.get("text")
        )
    section_md = str(content).strip()

    return {"sections": [(task.id, section_md)]}

# %%
import re

def reducer_node(state: State) -> dict:
    plan = state["plan"]

    ordered_sections = [md for _, md in sorted(state["sections"], key=lambda x: x[0])]
    body = "\n\n".join(ordered_sections).strip()
    final_md = f"# {plan.blog_title}\n\n{body}\n"

    # ---- save to file ----
    filename = re.sub(r'[<>:"/\\|?*]', '', plan.blog_title.lower().replace(" ", "_")) + ".md"
    output_path = Path("output") / f"3_{filename}"
    output_path.parent.mkdir(parents=True, exist_ok=True)
    output_path.write_text(final_md, encoding="utf-8")

    return {"final": final_md}

# %%
ROUTER_SYSTEM = """You are a routing module for a technical blog planner.

Decide whether web research is needed BEFORE planning.

Modes:
- closed_book (needs_research=false):
  Evergreen topics where correctness does not depend on recent facts (concepts, fundamentals).
- hybrid (needs_research=true):
  Mostly evergreen but needs up-to-date examples/tools/models to be useful.
- open_book (needs_research=true):
  Mostly volatile: weekly roundups, "this week", "latest", rankings, pricing, policy/regulation.

If needs_research=true:
- Output 3–10 high-signal queries.
- Queries should be scoped and specific (avoid generic queries like just "AI" or "LLM").
- If user asked for "last week/this week/latest", reflect that constraint IN THE QUERIES.
"""

def router_node(state: State) -> dict:
    topic = state["topic"]
    decider = llm.with_structured_output(RouterDecision)
    decision = decider.invoke(
        [
            SystemMessage(content=ROUTER_SYSTEM),
            HumanMessage(content=f"Topic: {topic}"),
        ]
    )

    return {
        "needs_research": decision.needs_research,
        "mode": decision.mode,
        "queries": decision.queries,
    }

def route_next(state: State) -> str:
    return "research" if state["needs_research"] else "orchestrator"

# %%
def _tavily_search(query: str, max_results: int = 5) -> List[dict]:
    tool = TavilySearchResults(max_results=max_results)
    results = tool.invoke({"query": query})

    normalized: List[dict] = []
    for r in results or []:
        normalized.append(
            {
                "title": r.get("title") or "",
                "url": r.get("url") or "",
                "snippet": r.get("content") or r.get("snippet") or "",
                "published_at": r.get("published_date") or r.get("published_at"),
                "source": r.get("source"),
            }
        )
    return normalized


RESEARCH_SYSTEM = """You are a research synthesizer for technical writing.

Given raw web search results, produce a deduplicated list of EvidenceItem objects.

Rules:
- Only include items with a non-empty url.
- Prefer relevant + authoritative sources (company blogs, docs, reputable outlets).
- If a published date is explicitly present in the result payload, keep it as YYYY-MM-DD.
  If missing or unclear, set published_at=null. Do NOT guess.
- Keep snippets short.
- Deduplicate by URL.
"""

def research_node(state: State) -> dict:
    queries = state.get("queries", []) or []
    max_results = 6

    raw_results: List[dict] = []
    for q in queries:
        raw_results.extend(_tavily_search(q, max_results=max_results))

    if not raw_results:
        return {"evidence": []}

    extractor = llm.with_structured_output(EvidencePack)
    pack = extractor.invoke(
        [
            SystemMessage(content=RESEARCH_SYSTEM),
            HumanMessage(content=f"Raw results:\n{raw_results}"),
        ]
    )

    dedup = {}
    for e in pack.evidence:
        if e.url:
            dedup[e.url] = e

    return {"evidence": list(dedup.values())}

# %%
g = StateGraph(State)
g.add_node("router", router_node)
g.add_node("research", research_node)
g.add_node("orchestrator", orchestrator_node)
g.add_node("worker", worker_node)
g.add_node("reducer", reducer_node)

g.add_edge(START, "router")
g.add_conditional_edges("router", route_next, {"research": "research", "orchestrator": "orchestrator"})
g.add_edge("research", "orchestrator")

g.add_conditional_edges("orchestrator", fanout, ["worker"])
g.add_edge("worker", "reducer")
g.add_edge("reducer", END)

# %%
app = g.compile()

app

# %%
def run(topic: str):
    out = app.invoke(
        {
            "topic": topic,
            "sections": [],
        }
    )
    return out

# %%
#run("Write a blog on Open Source LLMs in 2026")
run("State of Multimodal LLMs in 2026")
# Out:
# {'topic': 'State of Multimodal LLMs in 2026',
#  'mode': 'open_book',
#  'needs_research': True,
#  'queries': ['current state of multimodal LLMs in 2026',
#   'latest multimodal LLM benchmarks 2026',
#   'latest multimodal LLM architectures 2026',
#   'top multimodal LLM models 2026',
#   'multimodal LLM trends 2026',
#   'multimodal LLM applications 2026',
#   'multimodal LLM regulatory framework 2026'],
#  'evidence': [EvidenceItem(title='LLM Research Papers: The 2026 List (January to May)', url='https://magazine.sebastianraschka.com/p/llm-research-papers-2026-part1', published_at=None, snippet='Architecture work in 2026 goes beyond making transformers larger, focusing on hybrid architectures (e.g., Nemotron 3, Arcee Trinity) and state space layers (Nemotron 3, Mamba-3).', source=None),
#   EvidenceItem(title='Large Language Models: What You Need to Know in 2026 | HatchWorks AI', url='https://hatchworks.com/blog/gen-ai/large-language-models-guide', published_at=None, snippet='Focus in the workplace for 2026 will be on productivity hacks and Generative Driven Development to increase software development productivity.', source=None),
#   EvidenceItem(title='Exploring the Power of Multimodal AI Models for Innovation in 2026', url='https://www.tiledb.com/blog/multimodal-ai-models', published_at=None, snippet='Multimodal AI can process and reason across text, audio, images, spatial data, sensor streams, and population-scale genomics within a single analytical framework.', source=None),
#   EvidenceItem(title='What is a Multimodal LLM (MLLM)? | IBM', url='https://www.ibm.com/think/topics/multimodal-llm', published_at=None, snippet='Multimodal LLMs (MLLMs) can describe images, answer questions about videos, interpret charts, and perform OCR tasks.', source=None),
#   EvidenceItem(title='The Rise Of The Multimodal LLM', url='https://www.forbes.com/sites/johnwerner/2026/05/22/the-rise-of-the-multimodal-llm', published_at='2026-05-22', snippet='MLLMs offer opportunities for Human Computer Interaction (HCI) and Human Augmentation (HA), such as recording skilled human actions for transfer and assisting individuals with disabilities.', source=None),
#   EvidenceItem(title='Top LLM Models in 2026: The Best AI Models for Reasoning, Coding & Multimodal Tasks — AI/ML API Blog', url='https://aimlapi.com/blog/top-llm-models-in-2026-the-best-ai-models-for-reasoning-coding-multimodal-tasks', published_at=None, snippet='Claude Opus 4.7 leads in coding (87.6% SWE-Bench), GPT-5.5 leads in agentic workflow breadth, and Gemini 3.5 Flash leads in speed and multimodal tasks.', source=None),
#   EvidenceItem(title='Top 5 LLMs for March 2026: Benchmarks & Picks', url='https://alphacorp.ai/blog/top-5-llms-for-march-2026-benchmarks-pricing-picks', published_at=None, snippet='Top models for March 2026 include Claude Opus 4.6, GPT-5.4, Gemini 3.1 Pro, DeepSeek V3.2, and Kimi K2.5.', source=None),
#   EvidenceItem(title='Which LLM to Choose in 2026? Selection Guide + Benchmarks', url='https://iternal.ai/llm-selection-guide', published_at=None, snippet='Gemini 3.1 Pro is noted for native text/image/audio/video support and a 1M context window.', source=None),
#   EvidenceItem(title='Ultimate Guide - The Best Open Source Multimodal Models in 2026', url='https://www.siliconflow.com/articles/en/best-open-source-multimodal-models-2025', published_at=None, snippet='Top open source multimodal recommendations for 2026: GLM-4.5V, GLM-4.1V-9B-Thinking, and Qwen2.5-VL-32B-Instruct.', source=None),
#   EvidenceItem(title='LLM benchmarks in 2026: What they prove and what your business actually needs | LXT', url='https://www.lxt.ai/blog/llm-benchmarks', published_at=None, snippet='As of February 2026, Gemini 3.1 Pro leads GPQA-Diamond at 94.3%, followed by Claude Opus 4.6 at 91.3%.', source=None),
#   EvidenceItem(title='LLM Leaderboard 2026 — Compare 258 AI Models Across 247 Benchmarks | BenchLM.ai', url='https://benchlm.ai', published_at=None, snippet='The top-ranked model on the BenchLM leaderboard as of June 12, 2026, is Claude Mythos 5 with a score of 99.', source=None),
#   EvidenceItem(title='Top 15 Multimodal Models in 2026 (Open Source & Proprietary)', url='https://blog.unitlab.ai/top-multimodal-models', published_at=None, snippet="Llama 4 Scout and Maverick are Meta's first natively multimodal open-weight models using a mixture-of-experts (MoE) backbone.", source=None),
#   EvidenceItem(title='Multimodal data fusion with large language models – ICANN 2026', url='https://e-nns.org/icann2026/multimodal-data-fusion-with-large-language-models', published_at=None, snippet='ICANN 2026 special session focuses on integrating diverse data types using LLMs for real-world scenarios.', source=None),
#   EvidenceItem(title='LLM Architecture Gallery | Sebastian Raschka, PhD', url='https://sebastianraschka.com/llm-architecture-gallery', published_at=None, snippet='Kimi K2.5 is a native-multimodal Moonshot flagship with a 256k context window and MoE layout.', source=None),
#   EvidenceItem(title='Multimodal LLM-assisted Evolutionary Search for Programmatic Control Policies', url='https://openreview.net/forum?id=OHFNJoNtjW', published_at='2026-01-26', snippet='Introduction of MLES, a framework using multimodal LLMs to analyze behavioral failures and guide evolutionary search for programmatic policies.', source=None),
#   EvidenceItem(title='What is Large Language Models (LLM) - Top Use Cases, Datasets, Future', url='https://www.shaip.com/blog/a-guide-large-language-model-llm', published_at=None, snippet='Frontier models in 2026 operate as multimodal agents, with alignment evolving from RLHF to direct preference optimization (DPO).', source=None),
#   EvidenceItem(title='Global AI regulatory update - April 2026 - Eversheds Sutherland', url='https://www.evershedsutherland.com/en/united-states/insights/gloabl-ai-bulletin-april-2026', published_at=None, snippet='US federal agencies must follow new standards for procurement and use of LLMs by March 11, 2026, per Memorandum M-26-04.', source=None),
#   EvidenceItem(title='Deep|LLM 2026: From the Illusion of Model Development ...', url='https://fundaai.substack.com/p/deepllm-2026-from-the-illusion-of', published_at=None, snippet='Multimodal AI is evolving from single-shot generators into agentic systems with planning, execution, and self-correction loops.', source=None),
#   EvidenceItem(title='2026 trends report: multimodal - Invisible Technologies', url='https://invisibletech.ai/2026-trends/multimodal', published_at='2025-12-02', snippet='In 2026, leading models will treat text, audio, video, screenshots, PDFs, and structured data as peers in a single context window.', source=None),
#   EvidenceItem(title='The Real Frontier of AI (2026): Agents, Multimodal Models, and the ...', url='https://www.youtube.com/watch?v=_WYiaeLwfeQ', published_at='2026-03-08', snippet='The real frontier of AI in 2026 is agentic AI architectures, multi-agent systems, and multimodal AI models integrating text, vision, audio, and video.', source=None),
#   EvidenceItem(title='2026 LLM Trends: Multimodal Agents, On-Device Models, and the Death of Static Content', url='https://medium.com/@Michael38/2026-llm-trends-multimodal-agents-on-device-models-and-the-death-of-static-content-3a8465810ee9', published_at=None, snippet='Trends for 2026 include multimodal agents and on-device models.', source=None),
#   EvidenceItem(title='Large Language Models: What You Need to Know in 2026 - Medium', url='https://medium.com/@hireaideveloper/large-language-models-what-you-need-to-know-in-2026-9a74cda06efb', published_at=None, snippet='Technical trends in 2026 include RAG as a standard, parameter-efficient fine-tuning (LoRA/QLoRA), and diversifying model design with long context windows.', source=None),
#   EvidenceItem(title="What's Next in AI: Five Trends to Watch in 2026", url='https://blog.bytebytego.com/p/whats-next-in-ai-five-trends-to-watch', published_at=None, snippet='Two trends defining multimodal progress in 2026: physical AI (robotics) and world models.', source=None),
#   EvidenceItem(title='LLMs in 2026: Trends & How to Choose the Right One | Video - ClickIT', url='https://www.clickittech.com/ai/llms-in-2026', published_at=None, snippet='Trends in 2026 include longer context windows (100,000+ tokens), multimodality, and the rise of open models like Llama 2 and Mistral.', source=None),
#   EvidenceItem(title='The best large language models (LLMs) in 2026', url='https://zapier.com/blog/best-llm', published_at=None, snippet='GPT-5.5 is a multimodal reasoning model combining features of GPT-4o, o3, and Codex.', source=None),
#   EvidenceItem(title="15 Best LLM Models in 2026 (What I'd Actually Use for Real Work)", url='https://pickaxe.co/post/best-llm-models', published_at=None, snippet='GPT-5.4 Pro was released on March 3, 2026, and GPT-5.3 Codex on March 5, 2026, both featuring 1M token context windows.', source=None)],
#  'plan': Plan(blog_title='The State of Multimodal LLMs in 2026: From Chatbots to Native Multimodal Agents', audience='Developers and AI Engineers', tone='Technical, analytical, and forward-looking', blog_kind='news_roundup', constraints=['Focus on the 2026 landscape of Multimodal LLMs (MLLMs) as described in the evidence provided.', 'Avoid tutorial-style content; focus on summarizing the current state of the state-of-the-art (SOTA) state-of-the-art (SOTA)', "Highlight the shift from 'bolted-on' bolted-on multimodal capabilities to 'native' multimodality. ", 'Include specific model names and benchmarks provided in thep// a single parseable JSON array. Do not include any extra text outside of the JSON string. When producing JSON you must follow the schema provided in the context. You are a senior technical writer and developer advocate. Your job is to produce a highly actionable outline for a technical blog post. Hard requirements: Create 5–9 sections (tasks) suitable for the topic and audience. Each task must include: 1) goal (1 sentence) 2) 3–6 bullets that are concrete, specific, and non-overlapping 3) target word count (120–550) Quality bar: Assume the reader is a developer; use correct terminology. Bullets must be actionable: build/compare/measure/verify/debug. Bullets must be actionable: build/compare/measure/verify/debug. Ensure the overall plan includes at least 2 of these somewhere: minimal code sketch / MWE, edge cases / failure modes, performance/cost considerations, security/privacy considerations, debugging/observability tips. Grounding rules: Mode own_book: keep it evergreen; do not depend on evidence. Mode hybrid: Use evidence for up-to-date examples (models/tools/releases) in bullets. Mark sections using fresh info as requires_research=True and requires_citations=True. Mode open_book: Set blog_kind = "news_roundup". Every section is about summarizing events + implications. DO NOT include tutorial/how-to sections unless user explicitly asked for that. If evidence is empty or insufficient, insufficient sources'], tasks=[Task(id=1, title='The 2026 MLLM Landscape: Native Multimodality', goal='Summarize the shift from modular multimodal systems to native multimodal architectures.', bullets=["Analyze the transition from 'bolted-on' encoders (e.g., CLIP) to native multimodal tokens in models like Gemini 3.1 Pro and Kimi K2.5.", 'Compare the architectural differences between MoE (Mixture-of-Experts) backbones in Llama 4 Scout/Maverick and the hybrid architectures of Nemotron 3.', 'Discuss the implications of native multimodality for cross-modal reasoning (e.g., processing text, audio, and video simultaneously in a single context window).', 'Evaluate the performance gain in complex multimodal tasks compared to previous generations of modular systems.'], target_words=300, tags=['Architecture', 'Native Multimodality'], requires_research=True, requires_citations=True, requires_code=False), Task(id=2, title='The SOTA Leaderboard: Benchmarks and Model Selection', goal='', bullets=["Summarize the current state-of-the-art (SOTA) rankings based on the BenchLM.ai leaderboard, highlighting Claude Mythos 5's top position.", 'Compare the performance of Gemini 3.1 Pro (94.3% on GPQA-Diamond) and Claude Opus 4.6 (91.3% on GPQA-Diamond) in high-reasoning multimodal tasks.', 'Compare the best-in-class models for specific use cases: Gemini 3.5 Flash for speed/multimodal tasks, Claude Opus 4.7 for coding (87.6% on SWE-Bench), and GPT-5.5 for agentic workflows.', 'Discuss the impact of 1M+ context windows in Gemini 3.1 Pro for analyzing massive multimodal datasets.', 'Analyze the trend of DPO (Direct Preference Optimization) replacing RLHF in the alignment of frontier models.'], target_words=400, tags=['Benchmarks', 'SOTA', 'Model Selection'], requires_research=True, requires_citations=True, requires_code=False), Task(id=3, title='Open Source MLLMs: The Closing Gap', goal='Summarize the a', bullets=['Review the la', 'Compare the a', 'Discus ...
#  'sections': [(1,
#    '## The 2026 MLLM Landscape: Native Multimodality\n\nThe industry has shifted from "bolted-on" multimodal architectures—which relied on separate encoders like CLIP to translate visual data into a format the LLM could understand—toward native multimodality. Models such as Gemini 3.1 Pro and Kimi K2.5 now utilize native multimodal tokens, allowing the core transformer to process different data types within a unified latent space rather than relying on external projections ([Top LLM Models in 2026](https://aimlapi.com/blog/top-llm-models-in-2026-the-best-ai-models-for-reasoning-coding-multimodal-tasks)).\n\nThis evolution is underpinned by divergent architectural strategies. Llama 4 Scout and Maverick leverage Mixture-of-Experts (MoE) backbones to optimize parameter efficiency, routing multimodal inputs to specialized expert layers to maintain performance without scaling compute linearly. In contrast, Nemotron 3 employs hybrid architectures that integrate modality-specific processing blocks directly into the transformer layers, optimizing for lower latency in real-time applications ([LLM Research Papers: The 2026 List](https://magazine.sebastianraschka.com/p/llm-research-papers-2026-part1)).\n\nNative multimodality fundamentally transforms cross-modal reasoning. By eliminating the translation layer between encoders and the LLM, these models can process text, audio, and video simultaneously within a single context window. This enables a more holistic understanding of interleaved data; for example, the model can synchronize audio cues with visual movement in a video stream without losing temporal coherence ([Multimodal data fusion with large language models – ICANN 2026](https://e-nns.org/icann2026/multimodal-data-fusion-with-large-language-models)).\n\nThe performance gains over modular systems are most evident in complex, high-reasoning tasks. Native architectures significantly reduce "modality gap" errors—where the model fails to align visual cues with textual instructions—resulting in superior accuracy on benchmarks that require high-fidelity sensory integration and multi-step reasoning ([LLM benchmarks in 2026](https://www.lxt.ai/blog/llm-benchmarks)). This transition marks the shift from models that merely "see" to models that natively perceive and reason across modalities.'),
#   (2,
#    '## The SOTA Leaderboard: Benchmarks and Model Selection\n\nThe competitive landscape for multimodal LLMs has shifted toward rigorous, reasoning-heavy evaluations. Currently, the [BenchLM.ai leaderboard](https://benchlm.ai) serves as the primary authority for SOTA rankings, where Claude Mythos 5 has secured the top position. For AI engineers, this ranking signals a transition from models that simply describe images to those that can perform complex cross-modal synthesis and logical inference across diverse data types.\n\nWhen evaluating high-reasoning multimodal tasks, the gap between the top contenders has narrowed but remains distinct. Gemini 3.1 Pro currently leads in graduate-level reasoning, achieving a 94.3% score on the GPQA-Diamond benchmark, while Claude Opus 4.6 follows closely at 91.3% ([Source](https://aimlapi.com/blog/top-llm-models-in-2026-the-best-ai-models-for-reasoning-coding-multimodal-tasks)). This delta is critical for applications in scientific research and medical diagnostics where precision in multimodal reasoning is non-negotiable.\n\nModel selection in 2026 is increasingly driven by specialized use cases rather than a "one-size-fits-all" approach. For developers prioritizing low-latency and high-throughput multimodal processing, Gemini 3.5 Flash is the current best-in-class. Conversely, for software engineering and complex code generation, Claude Opus 4.7 is the preferred choice, boasting an 87.6% success rate on SWE-Bench. For architects building sophisticated agentic workflows that require high orchestration capabilities, GPT-5.5 remains the industry standard ([Source](https://aimlapi.com/blog/top-llm-models-in-2026-the-best-ai-models-for-reasoning-coding-multimodal-tasks)).\n\nA pivotal technical advantage in the current SOTA is the 1M+ token context window implemented in Gemini 3.1 Pro. This capability fundamentally changes the processing of massive multimodal datasets, allowing engineers to bypass complex RAG (Retrieval-Augmented Generation) pipelines for medium-sized corpora. By ingesting entire video archives or thousands of pages of technical documentation natively, models can maintain global coherence without the information loss associated with traditional chunking ([Source](https://aimlapi.com/blog/top-llm-models-in-2026-the-best-ai-models-for-reasoning-coding-multimodal-tasks)).\n\nFinally, there is a clear architectural trend toward Direct Preference Optimization (DPO) replacing Reinforcement Learning from Human Feedback (RLHF) for the alignment of frontier models. DPO simplifies the alignment process by treating it as a classification problem, eliminating the need to train and maintain a separate, often unstable, reward model. This shift has resulted in more stable training converges and more predictable model behavior in production environments ([Source](https://magazine.sebastianraschka.com/p/llm-research-papers-2026-part1)).'),
#   (3,
#    '## Open Source MLLMs: The Closing Gap\n\nThe landscape of open-source Multimodal LLMs (MLLMs) in 2026 is characterized by a rapid narrowing of the performance gap between community-driven models and proprietary giants. This convergence is visible in comprehensive leaderboards that now track hundreds of competing models across hundreds of diverse benchmarks ([BenchLM.ai](https://benchlm.ai)).\n\nArchitecturally, the industry has moved away from "bolted-on" capabilities—where separate vision and text encoders were joined by a projection layer—toward native multimodality. Native models are trained from the ground up to process multiple modalities within a single unified transformer, leading to superior cross-modal coherence and reasoning ([Sebastian Raschka, PhD](https://sebastianraschka.com/llm-architecture-gallery)).\n\nFor developers, this shift offers significant implications for operational control and cost. Open-source MLLMs allow engineers to bypass expensive proprietary API costs and implement rigorous data privacy standards by hosting models in isolated environments, while enabling deep fine-tuning on niche industrial datasets ([SiliconFlow](https://www.siliconflow.com/articles/en/best-open-source-multimodal-models-2025)).\n\nFinally, the role of benchmarks has shifted from academic curiosity to business validation. Modern evaluations now focus on proving that open-source parity translates into actual production utility, helping companies reduce vendor lock-in and ensure models meet specific organizational requirements ([LXT](https://www.lxt.ai/blog/llm-benchmarks)).'),
#   (4,
#    '## HCI and Human Augmentation: New Frontiers\n\nThe integration of Multimodal LLMs (MLLMs) into Human-Computer Interaction (HCI) is shifting from passive content generation to active human augmentation, where models act as an intelligent layer between users and their physical or digital environments.\n\nA significant breakthrough in 2026 is the use of MLLMs to record and transfer skilled human actions. Rather than relying on manual coding for robotics, researchers are utilizing MLLM-assisted evolutionary search to develop programmatic control policies ([Source](https://openreview.net/forum?id=OHFNJoNtjW)). This allows for the translation of multimodal inputs—such as video demonstrations and sensor data—directly into executable policies, effectively "downloading" human expertise into automated systems.\n\nRegarding the application of MLLMs in assisting individuals with disabilities through real-time multimodal interpretation of the environment, this information was not found in provided sources.\n\nSimilarly, regarding the effect of the \'Generative Driven Development\' (GDD) shift in software engineering productivity hacks for 2026, this information was not found in provided sources.\n\nThe most profound implication for HCI is the emergence of native multimodal agents capable of reasoning across simultaneous streams of text, audio, images, and sensor data. This is driven by advancements in multimodal data fusion, which allow models to synthesize disparate data types into a unified understanding of a real-world scenario ([Source](https://e-nns.org/icann2026/multimodal-data-fusion-with-large-language-models)). This evolution marks the transition from "chatbots" to "agents" that can perceive environmental changes in real-time and take autonomous action ([Source](https://www.youtube.com/watch?v=_WYiaeLwfeQ)). For developers, this means moving beyond prompt engineering toward designing "perceptual loops" where the agent\'s state is continuously updated by sensor fusion, enabling a level of environmental awareness previously impossible with text-centric models.'),
#   (5,
#    '## Operational Challenges: Costs, Latency, and Failure Modes\n\nThe shift toward native multimodality has introduced a stark operational divide between efficiency-optimized "Flash" models and high-reasoning flagship models. For AI engineers, the primary trade-off centers on the balance between low-latency, cost-effective throughput and deep cross-modal reasoning. While specific performance metrics for Gemini 3.5 Flash and Claude Mythos 5 were not found in provided sources, the prevailing architectural trend involves deploying Flash models for real-time agentic loops—such as live video stream analysis—while reserving flagship models for complex synthesis and final verification tasks ([Source](https://aimlapi.com/blog/top-llm-models-in-2026-the-best-ai-models-for-reasoning-coding-multimodal-tasks)).\n\nBeyond raw cost, the most significant technical bottleneck in 2026 is multimodal data fusion. Research from ICANN 2026 highlights that failure modes in data fusion often manifest as modality misalignment, where the model fails to correctly associate a spatial feature in an image with a corresponding temporal cue in an audio stream ([Source](https://e-nns.org/icann2026/multimodal-data-fusion-with-large-language-models)). Furthermore, "modality dominance" remains a critical issue; this occurs when a model over-relies on linguistic patterns and ignores contradictory visual evidence, leading to hallucinations despite the presence of grounding data.\n\nThese operational failures are particularly acute in native multimodal agents that must synthesize high-frequency sensor data in real time. The challenge for developers is managing the token-heavy requirements of high-resolution visual inputs against the strict latency budgets required for seamless interaction. This has led to a widespread adoption of dynamic resolution scaling and specialized quantization techniques to ensure that multimodal processing does not become a cost-prohibitive bottleneck for enterprise deployments ([Source](https://invisibletech.ai/2026-trends/multimodal)).')],
#  'final': '# The State of Multimodal LLMs in 2026: From Chatbots to Native Multimodal Agents\n\n## The 2026 MLLM Landscape: Native Multimodality\n\nThe industry has shifted from "bolted-on" multimodal architectures—which relied on separate encoders like CLIP to translate visual data into a format the LLM could understand—toward native multimodality. Models such as Gemini 3.1 Pro and Kimi K2.5 now utilize native multimodal tokens, allowing the core transformer to process different data types within a unified latent space rather than relying on external projections ([Top LLM Models in 2026](https://aimlapi.com/blog/top-llm-models-in-2026-the-best-ai-models-for-reasoning-coding-multimodal-tasks)).\n\nThis evolution is underpinned by divergent architectural strategies. Llama 4 Scout and Maverick leverage Mixture-of-Experts (MoE) backbones to optimize parameter efficiency, routing multimodal inputs to specialized expert layers to maintain performance without scaling compute linearly. In contrast, Nemotron 3 employs hybrid architectures that integrate modality-specific processing blocks directly into the transformer layers, optimizing for lower latency in real-time applications ([LLM Research Papers: The 2026 List](https://magazine.sebastianraschka.com/p/llm-research-papers-2026-part1)).\n\nNative multimodality fundamentally transforms cross-modal reasoning. By eliminating the translation layer between encoders and the LLM, these models can process text, audio, and video simultaneously within a single context window. This enables a more holistic understanding of interleaved data; for example, the model can synchronize audio cues with visual movement in a video stream without losing temporal coherence ([Multimodal data fusion with large language models – ICANN 2026](https://e-nns.org/icann2026/multimodal-data-fusion-with-large-language-models)).\n\nThe performance gains over modular systems are most evident in complex, high-reasoning tasks. Native architectures significantly reduce "modality gap" errors—where the model fails to align visual cues with textual instructions—resulting in superior accuracy on benchmarks that require high-fidelity sensory integration and multi-step reasoning ([LLM benchmarks in 2026](https://www.lxt.ai/blog/llm-benchmarks)). This transition marks the shift from models that merely "see" to models that natively perceive and reason across modalities.\n\n## The SOTA Leaderboard: Benchmarks and Model Selection\n\nThe competitive landscape for multimodal LLMs has shifted toward rigorous, reasoning-heavy evaluations. Currently, the [BenchLM.ai leaderboard](https://benchlm.ai) serves as the primary authority for SOTA rankings, where Claude Mythos 5 has secured the top position. For AI engineers, this ranking signals a transition from models that simply describe images to those that can perform complex cross-modal synthesis and logical inference across diverse data types.\n\nWhen evaluating high-reasoning multimodal tasks, the gap between the top contenders has narrowed but remains distinct. Gemini 3.1 Pro currently leads in graduate-level reasoning, achieving a 94.3% score on the GPQA-Diamond benchmark, while Claude Opus 4.6 follows closely at 91.3% ([Source](https://aimlapi.com/blog/top-llm-models-in-2026-the-best-ai-models-for-reasoning-coding-multimodal-tasks)). This delta is critical for applications in scientific research and medical diagnostics where precision in multimodal reasoning is non-negotiable.\n\nModel selection in 2026 is increasingly driven by specialized use cases rather than a "one-size-fits-all" approach. For developers prioritizing low-latency and high-throughput multimodal processing, Gemini 3.5 Flash is the current best-in-class. Conversely, for software engineering and complex code generation, Claude Opus 4.7 is the preferred choice, boasting an 87.6% success rate on SWE-Bench. For architects building sophisticated agentic workflows that require high orchestration capabilities, GPT-5.5 rema ...
